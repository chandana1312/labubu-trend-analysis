# %% [markdown]
# # 📈 The Rise of Labubu: A Trend Analysis in Designer Toys (Gen Z Edition)

# %% [markdown]
# ## ✅ PHASE 1: Setup Your Project in Google Colab

# %%
# !pip install pytrends snscrape matplotlib seaborn wordcloud textblob
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 2.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## ✅ PHASE 2: Collect Data

# %%
from pytrends.request import TrendReq
import pandas as pd

pytrends = TrendReq(hl='en-US', tz=330)
keywords = ['Labubu', 'Bathroom Camping', 'Fake Weddings', 'Yearning']
pytrends.build_payload(keywords, cat=0, timeframe='2022-01-01 2025-07-01', geo='', gprop='')
trend_data = pytrends.interest_over_time()
trend_data.head()
# Out:
#             Labubu  Bathroom Camping  Fake Weddings  Yearning  isPartial
# date
# 2021-12-26       0                 0              0         0      False
# 2022-01-02       0                 0              0         0      False
# 2022-01-09       0                 0              0         0      False
# 2022-01-16       0                 0              0         0      False
# 2022-01-23       0                 0              0         0      False

# %%
import pandas as pd
import random
from datetime import datetime, timedelta

sample_texts = [
    "I just got my first Labubu! 😍", "Labubu-core is real 🔥",
    "Honestly Labubu gives me so much serotonin 💖", "Why is Labubu trending again?",
    "I need more Labubu in my life 🐰✨", "Feeling that #yearning vibe with Labubu rn"
]

# Generate 100 fake tweets from Jan 2022 to July 2025
dates = [datetime(2022, 1, 1) + timedelta(days=random.randint(0, 1275)) for _ in range(100)]
contents = [random.choice(sample_texts) for _ in range(100)]
users = [f"user_{i}" for i in range(100)]

df_labubu = pd.DataFrame({'Date': dates, 'Content': contents, 'User': users})
df_labubu['Date'] = pd.to_datetime(df_labubu['Date'])
df_labubu.head()
# Out:
#         Date                                       Content    User
# 0 2023-09-17  Honestly Labubu gives me so much serotonin 💖  user_0
# 1 2024-12-08                 Why is Labubu trending again?  user_1
# 2 2025-04-19    Feeling that #yearning vibe with Labubu rn  user_2
# 3 2023-03-05                         Labubu-core is real 🔥  user_3
# 4 2022-03-11                         Labubu-core is real 🔥  user_4
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.11/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 128150 (\N{SPARKLING HEART}) missing from font(s) DejaVu Sans.
#   plt.savefig(
# /usr/local/lib/python3.11/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning: Glyph 128293 (\N{FIRE}) missing from font(s) DejaVu Sans.
#   plt.savefig(
# ...

# %% [markdown]
# ## ✅ PHASE 3: Clean & Preprocess the Data

# %%
df_labubu['Date'] = pd.to_datetime(df_labubu['Date'])
df_labubu['Content'] = df_labubu['Content'].str.lower()

# %%
from textblob import TextBlob
df_labubu['Sentiment'] = df_labubu['Content'].apply(lambda x: TextBlob(x).sentiment.polarity)

# %% [markdown]
# ## ✅ PHASE 4: Analyze Trends and Gen Z Behavior

# %%
import matplotlib.pyplot as plt

trend_data[keywords].plot(figsize=(12,6))
plt.title('📊 Google Search Interest Over Time')
plt.xlabel('Date')
plt.ylabel('Search Interest')
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import seaborn as sns

df_labubu['Month'] = df_labubu['Date'].dt.to_period('M')
monthly_sentiment = df_labubu.groupby('Month')['Sentiment'].mean()
monthly_sentiment.plot(kind='line', figsize=(12,5), title='💬 Average Sentiment Over Time (Labubu)')
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128172 (\N{SPEECH BALLOON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128172 (\N{SPEECH BALLOON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128172 (\N{SPEECH BALLOON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from wordcloud import WordCloud

text = " ".join(df_labubu['Content'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(12,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('☁️ Labubu Mentions WordCloud')
plt.show()

# %% [markdown]
# ## ✅ PHASE 5: Compare With Gen Z Micro-Trends

# %%
import pandas as pd
import random
from datetime import datetime, timedelta
from textblob import TextBlob

# Define mock tweets for each Gen Z trend
mock_texts = {
    "#bathroomcamping": [
        "Bathroom camping is the new self-care ⛺🛁", "Just pitched a tent in my tub 😂",
        "Another Friday night of bathroom camping ✨", "Honestly, it helps me reset"
    ],
    "#fakeweddings": [
        "Had a fake wedding for content and cried real tears 😭", "Fake wedding but real drama!",
        "Would you attend a fake wedding for the aesthetic?", "This shoot felt too real 😳"
    ],
    "#yearning": [
        "Yearning season is back 🍂💔", "Not sad, just in my yearning era",
        "This playlist is giving peak yearningcore vibes", "I miss people I never met"
    ]
}

queries = ['#bathroomcamping', '#fakeweddings', '#yearning']
dfs = {}

for tag in queries:
    tweets = []
    for i in range(100):  # generate 100 tweets per trend
        date = datetime(2022, 1, 1) + timedelta(days=random.randint(0, 1275))
        content = random.choice(mock_texts[tag])
        user = f"user_{tag[1:]}_{i}"
        tweets.append([date, content, user])

    df = pd.DataFrame(tweets, columns=['Date', 'Content', 'User'])
    df['Date'] = pd.to_datetime(df['Date'])
    df['Content'] = df['Content'].str.lower()
    df['Sentiment'] = df['Content'].apply(lambda x: TextBlob(x).sentiment.polarity)
    df['Month'] = df['Date'].dt.to_period('M')
    dfs[tag] = df

# Preview one dataframe
dfs['#bathroomcamping'].head()
# Out:
#         Date                                     Content  \
# 0 2024-09-15             just pitched a tent in my tub 😂
# 1 2023-10-23  another friday night of bathroom camping ✨
# 2 2022-07-28  another friday night of bathroom camping ✨
# 3 2023-07-03                 honestly, it helps me reset
# 4 2024-03-07    bathroom camping is the new self-care ⛺🛁
#
#                      User  Sentiment    Month
# 0  user_bathroomcamping_0   0.000000  2024-09
# 1  user_bathroomcamping_1   0.000000  2023-10
# 2  user_bathroomcamping_2   0.000000  2022-07
# 3  user_bathroomcamping_3   0.600000  2023-07
# 4  user_bathroomcamping_4   0.136364  2024-03
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['Month'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7['Sentiment'].plot(kind='hist', bins=20, title='Sentiment')
# ...

# %%
plt.figure(figsize=(12,6))
for tag, df in dfs.items():
    monthly_sentiment = df.groupby('Month')['Sentiment'].mean()
    monthly_sentiment.plot(label=tag)
plt.title('📈 Sentiment Comparison Across Gen Z Trends')
plt.xlabel('Month')
plt.ylabel('Average Sentiment')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
for tag, df in dfs.items():
    text = " ".join(df['Content'])
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(12,6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f'☁️ WordCloud for {tag}')
    plt.show()

# %%
df_labubu.to_csv("labubu_tweets.csv", index=False)
for tag, df in dfs.items():
    df.to_csv(f"{tag.strip('#')}_tweets.csv", index=False)
